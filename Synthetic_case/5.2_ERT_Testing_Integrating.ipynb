# %% [markdown]
# # ERT simulation

# %%
import matplotlib.pyplot as plt
import numpy as np

import pygimli as pg
import pygimli.meshtools as mt
from pygimli.physics import ert

# %% [markdown]
# ### Invert

# %%
#mgr = ert.ERTManager('simple.dat')
data= pg.load('data/ERTLine_f.dat')
ert.showData(data, cMap='viridis')
# Out:
# (<Axes: >, <matplotlib.colorbar.Colorbar at 0x7f3b15ec3a90>)

# %%
xz = np.load('models/boundary.npy')

# %%
plc = mt.createParaMeshPLC(data, paraDepth=10, boundary=1)
line = mt.createPolygon(xz, marker=1)
plc += line
mesh = mt.createMesh(plc, quality=34.3)
pg.show(mesh, markers=True, showMesh=True)
# Out:
# (<Axes: >, <matplotlib.colorbar.Colorbar at 0x7f3b340cf5d0>)

# %%
mgr = ert.Manager(data)
mgr.setMesh(mesh)
mgr.invert(verbose=False)
# Out:
# 20/04/24 - 22:13:25 - pyGIMLi - INFO - Found 2 regions.
# 20/04/24 - 22:13:25 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 20/04/24 - 22:13:25 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 20/04/24 - 22:13:26 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 20/04/24 - 22:13:26 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 4770 Cells: 9156 Boundaries: 7058
# 20/04/24 - 22:13:26 - pyGIMLi - INFO - Use median(data values)=20.2631430997752
# 20/04/24 - 22:13:26 - pyGIMLi - INFO - Created startmodel from forward operator: 1737, min/max=20.263143/20.263143
# 20/04/24 - 22:13:26 - pyGIMLi - INFO - Starting inversion.
# min/max(dweight) = 1.27249/99.9981
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x7f3b3444b1a0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x7f3b3444b4c0>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x7f3b3444b3d0>
# min/max (data): 0.17/52.16
# min/max (error): 1%/78.59%
# min/max (start model): 20.26/20.26
# --------------------------------------------------------------------------------
# Calculating response for model: min = 20.2631 max = 20.2631
# Allocating memory for primary potential...... 0.0606417
#
# No primary potential for secondary field calculation. Calculating analytically...
# Forward: time: 1.99267s
# Response: min = 20.203 max = 20.2895 mean = 20.2582
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# min/max(dweight) = 1.27249/99.9981
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 2511 x 1737
# check Jacobian: wrong dimensions: (0x0) should be (2415x1737)  force: 1
# jacobian size invalid, forced recalc: 1
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0546036:time: 9.15746s
# inv.iter 0 ... chi² = 3743.44
# --------------------------------------------------------------------------------
# inv.iter 1 ... sens sum: median = 1.03622 min = 0.963297 max = 1.3067
# ... 9.17245 s
# min data = 0.167608 max data = 52.1591 (2415)
# min error = 0.0100002 max error = 0.785859 (2415)
# min response = 20.203 max response = 20.2895 (2415)
# calc without reference model
# 0: rms/rrms(data, response) = 20.3069/830.244%
# 0: chi^2(data, response, error, log) = 3743.44
# 0: Phi = 9.04042e+06 + 0 * 20 = 9.04042e+06
# solve CGLSCDWWtrans with lambda = 20
# chi² =  625.69 (dPhi = 83.19%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... Calculating response for model: min = 4.42979e-05 max = 170.719
# Using existing primary potentials.
# Forward: time: 1.39041s
# Response: min = 0.0908742 max = 52.4509 mean = 27.229
# Reciprocity rms(modelReciprocity) 3.36869%, max: 5.43369%
# Performing line search with tau = 1
# 1: Model: min = 4.42979e-05; max = 170.719
# 1: Response: min = 0.140472; max = 52.1436
# 1: rms/rrms(data, Response) = 6.07623/115.334%
# 1: chi^2(data, Response, error, log) = 625.693
# 1: Phi = 1.51105e+06+422.095*20=1.51949e+06
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0045274:time: 8.88404s
# sens sum: median = 1.44363 min = 0.954859 max = 4.33188
# ... 8.89659 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.0314199 max = 383.027
# Using existing primary potentials.
# Forward: time: 1.53048s
# Response: min = 0.162141 max = 52.9992 mean = 24.5746
# Reciprocity rms(modelReciprocity) 2.01417%, max: 9.60721%
# chi² =  188.64 (dPhi = 69.72%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... Performing line search with tau = 0.96
# 2: Model: min = 0.0314199; max = 383.027
# 2: Response: min = 0.176432; max = 53.2011
# 2: rms/rrms(data, Response) = 3.47569/29.1313%
# 2: chi^2(data, Response, error, log) = 188.64
# 2: Phi = 455566+230.566*20=460177
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0037671:time: 8.79579s
# sens sum: median = 1.29587 min = 0.101987 max = 2.31676
# ... 8.80955 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 1.28493 max = 168.947
# Using existing primary potentials.
# Forward: time: 1.42141s
# Response: min = 1.9112 max = 73.1591 mean = 28.7232
# Reciprocity rms(modelReciprocity) 2.83913%, max: 4.4473%
# tau = 0.02. Trying parabolic line search with step length 0.3Calculating response for model: min = 0.106528 max = 160.261
# Using existing primary potentials.
# Forward: time: 1.38726s
# Response: min = 0.627556 max = 52.6832 mean = 24.8484
# Reciprocity rms(modelReciprocity) 1.71231%, max: 6.54187%
# chi² =  133.04 (dPhi = 29.59%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 4 ...  ==> tau = 0.258735
# 3: LS newModel: min = 1.28493; max = 168.947
# 3: LS newResponse: min = 1.99599; max = 73.158
# 3: rms/rrms(data, LS newResponse) = 7.68696/294.602%
# 3: chi^2(data, LS newResponse, error, log) = 605.741
# 3: Phi = 1.46286e+06+70.7711*20=1.46428e+06
# Performing line search with tau = 0.258735
# Calculating response for model: min = 0.0900587 max = 179.339
# Using existing primary potentials.
# Forward: time: 1.45295s
# Response: min = 0.530667 max = 52.4728 mean = 24.7611
# Reciprocity rms(modelReciprocity) 1.71244%, max: 6.85495%
# 3: Model: min = 0.0900587; max = 179.339
# 3: Response: min = 0.573942; max = 52.6755
# 3: rms/rrms(data, Response) = 2.81432/36.4356%
# 3: chi^2(data, Response, error, log) = 133.042
# 3: Phi = 321298+135.721*20=324012
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0081618:time: 8.75999s
# sens sum: median = 1.26931 min = 0.227572 max = 2.13791
# ... 8.77542 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.739748 max = 166.431
# Using existing primary potentials.
# Forward: time: 1.47895s
# Response: min = 1.30762 max = 54.9955 mean = 28.1865
# Reciprocity rms(modelReciprocity) 1.21685%, max: 3.09969%
# tau = 0. Trying parabolic line search with step length 0.3Calculating response for model: min = 0.170932 max = 136.916
# Using existing primary potentials.
# Forward: time: 1.45335s
# Response: min = 0.772998 max = 52.0442 mean = 24.8782
# Reciprocity rms(modelReciprocity) 1.49287%, max: 5.27762%
# chi² =   96.68 (dPhi = 27.42%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 5 ...  ==> tau = 0.24067
# 4: LS newModel: min = 0.739748; max = 166.431
# 4: LS newResponse: min = 1.36005; max = 54.8776
# 4: rms/rrms(data, LS newResponse) = 5.75146/90.5085%
# 4: chi^2(data, LS newResponse, error, log) = 506.771
# 4: Phi = 1.22385e+06+21.7233*20=1.22429e+06
# Performing line search with tau = 0.24067
# Calculating response for model: min = 0.150586 max = 144.423
# Using existing primary potentials.
# Forward: time: 1.43095s
# Response: min = 0.731175 max = 52.0971 mean = 24.8063
# Reciprocity rms(modelReciprocity) 1.53574%, max: 5.58516%
# 4: Model: min = 0.150586; max = 144.423
# 4: Response: min = 0.759166; max = 52.3093
# 4: rms/rrms(data, Response) = 2.3775/38.1523%
# 4: chi^2(data, Response, error, log) = 96.6791
# 4: Phi = 233480+83.5961*20=235152
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0044195:time: 8.761s
# sens sum: median = 1.2183 min = 0.247104 max = 1.9953
# ... 8.77673 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.498293 max = 107.154
# Using existing primary potentials.
# Forward: time: 1.43761s
# Response: min = 0.909593 max = 52.6215 mean = 26.9685
# Reciprocity rms(modelReciprocity) 1.43485%, max: 3.30014%
# tau = 0. Trying parabolic line search with step length 0.3Calculating response for model: min = 0.215623 max = 123.411
# Using existing primary potentials.
# Forward: time: 1.48307s
# Response: min = 0.804645 max = 51.7281 mean = 24.8319
# Reciprocity rms(modelReciprocity) 1.42525%, max: 4.07803%
# chi² =   66.50 (dPhi = 31.27%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 6 ...  ==> tau = 0.274013
# 5: LS newModel: min = 0.498293; max = 107.154
# 5: LS newResponse: min = 0.959155; max = 52.7204
# 5: rms/rrms(data, LS newResponse) = 3.96734/51.1383%
# 5: chi^2(data, LS newResponse, error, log) = 287.652
# 5: Phi = 694680+17.5039*20=695030
# Performing line search with tau = 0.274013
# Calculating response for model: min = 0.20902 max = 125.104
# Using existing primary potentials.
# Forward: time: 1.45014s
# Response: min = 0.798505 max = 51.7496 mean = 24.8113
# Reciprocity rms(modelReciprocity) 1.4335%, max: 4.20671%
# 5: Model: min = 0.20902; max = 125.104
# 5: Response: min = 0.83344; max = 51.9508
# 5: rms/rrms(data, Response) = 1.95767/35.5306%
# 5: chi^2(data, Response, error, log) = 66.5014
# 5: Phi = 160601+50.3919*20=161609
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0039028:time: 8.8055s
# sens sum: median = 1.17674 min = 0.263394 max = 1.90355
# ... 8.81938 s
# solve CGLSCDWWtrans with lambda = 20
# chi² =   43.61 (dPhi = 34.47%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 7 ... Calculating response for model: min = 0.452564 max = 107.638
# Using existing primary potentials.
# Forward: time: 1.46069s
# Response: min = 0.846249 max = 52.1919 mean = 26.0004
# Reciprocity rms(modelReciprocity) 1.60777%, max: 2.12707%
# tau = 0. Trying parabolic line search with step length 0.3Calculating response for model: min = 0.263534 max = 115.421
# Using existing primary potentials.
# Forward: time: 1.4032s
# Response: min = 0.833986 max = 51.5004 mean = 24.7864
# Reciprocity rms(modelReciprocity) 1.41746%, max: 2.91444%
#  ==> tau = 0.32254
# 6: LS newModel: min = 0.452564; max = 107.638
# 6: LS newResponse: min = 0.892782; max = 52.031
# 6: rms/rrms(data, LS newResponse) = 2.6765/36.966%
# 6: chi^2(data, LS newResponse, error, log) = 144.156
# 6: Phi = 348138+12.1364*20=348381
# Performing line search with tau = 0.32254
# Calculating response for model: min = 0.268162 max = 115.162
# Using existing primary potentials.
# Forward: time: 1.43677s
# Response: min = 0.836156 max = 51.498 mean = 24.7975
# Reciprocity rms(modelReciprocity) 1.41788%, max: 2.81866%
# 6: Model: min = 0.268162; max = 115.162
# 6: Response: min = 0.867714; max = 51.6463
# 6: rms/rrms(data, Response) = 1.55965/32.5936%
# 6: chi^2(data, Response, error, log) = 43.613
# 6: Phi = 105325+28.7446*20=105900
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0034782:time: 8.85825s
# chi² =   28.90 (dPhi = 33.93%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 8 ... sens sum: median = 1.14931 min = 0.296029 max = 1.82984
# ... 8.87328 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.529755 max = 100.034
# Using existing primary potentials.
# Forward: time: 1.42985s
# Response: min = 0.879878 max = 51.5363 mean = 25.1157
# Reciprocity rms(modelReciprocity) 1.73436%, max: 1.01704%
# 7: LS newModel: min = 0.529755; max = 100.034
# 7: LS newResponse: min = 0.933281; max = 51.5783
# 7: rms/rrms(data, LS newResponse) = 1.28981/32.1026%
# 7: chi^2(data, LS newResponse, error, log) = 36.313
# 7: Phi = 87696+7.9969*20=87855.9
# Performing line search with tau = 0.86
# Calculating response for model: min = 0.481593 max = 102.026
# Using existing primary potentials.
# Forward: time: 1.4343s
# Response: min = 0.887949 max = 51.4708 mean = 24.9836
# Reciprocity rms(modelReciprocity) 1.64535%, max: 1.13922%
# 7: Model: min = 0.481593; max = 102.026
# 7: Response: min = 0.935514; max = 51.548
# 7: rms/rrms(data, Response) = 1.1582/31.9052%
# 7: chi^2(data, Response, error, log) = 28.9045
# 7: Phi = 69804.3+8.1281*20=69966.9
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0034608:time: 9.22193s
# sens sum: median = 1.12228 min = 0.44107 max = 1.67126
# ... 9.2376 s
# solve CGLSCDWWtrans with lambda = 20
# chi² =    2.07 (dPhi = 92.65%) lam: 20.0Calculating response for model: min = 0.704183 max = 74.2524
# Using existing primary potentials.
# Forward: time: 1.53063s
# Response: min = 1.18062 max = 51.5432 mean = 24.4935
# Reciprocity rms(modelReciprocity) 1.38009%, max: 1.5424%
# Performing line search with tau = 1
# 8: Model: min = 0.704183; max = 74.2524
# 8: Response: min = 1.19805; max = 51.5498
# 8: rms/rrms(data, Response) = 0.413624/42.903%
# 8: chi^2(data, Response, error, log) = 2.0692
# 8: Phi = 4997.13+7.23399*20=5141.81
#
# --------------------------------------------------------------------------------
# inv.iter 9 ... Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0056301:time: 9.45862s
# sens sum: median = 1.21218 min = 0.683829 max = 1.80968
# ... 9.47227 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.600184 max = 70.9614
# Using existing primary potentials.
# Forward: time: 1.47032s
# Response: min = 0.966808 max = 51.5635 mean = 24.3753
# Reciprocity rms(modelReciprocity) 1.43766%, max: 1.86177%
# chi² =    1.01 (dPhi = 49.87%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 10 ... Performing line search with tau = 1
# 9: Model: min = 0.600184; max = 70.9614
# 9: Response: min = 0.981446; max = 51.5661
# 9: rms/rrms(data, Response) = 0.320809/30.7796%
# 9: chi^2(data, Response, error, log) = 1.01062
# 9: Phi = 2440.64+6.83744*20=2577.39
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0040238:time: 8.75816s
# sens sum: median = 1.16592 min = 0.654701 max = 1.74777
# ... 8.77164 s
# solve CGLSCDWWtrans with lambda = 20
# chi² =    0.97 (dPhi = 3.62%) lam: 20.0
#
#
# ################################################################################
# #                  Abort criterion reached: chi² <= 1 (0.97)                   #
# ################################################################################
# Calculating response for model: min = 0.588029 max = 70.3207
# Using existing primary potentials.
# Forward: time: 1.4044s
# Response: min = 1.0484 max = 51.5898 mean = 24.3849
# Reciprocity rms(modelReciprocity) 1.30521%, max: 1.79541%
# 10: LS newModel: min = 0.588029; max = 70.3207
# 10: LS newResponse: min = 1.06266; max = 51.5991
# 10: rms/rrms(data, LS newResponse) = 0.320859/34.4985%
# 10: chi^2(data, LS newResponse, error, log) = 0.983691
# 10: Phi = 2375.61+6.89296*20=2513.47
# Performing line search with tau = 0.64
# Calculating response for model: min = 0.59368 max = 68.3476
# Using existing primary potentials.
# Forward: time: 1.50689s
# Response: min = 1.01844 max = 51.5807 mean = 24.3812
# Reciprocity rms(modelReciprocity) 1.35032%, max: 1.81908%
# 10: Model: min = 0.59368; max = 68.3476
# 10: Response: min = 1.03282; max = 51.5875
# 10: rms/rrms(data, Response) = 0.318754/33.0878%
# 10: chi^2(data, Response, error, log) = 0.972434
# 10: Phi = 2348.43+6.77683*20=2483.96

# %%
mgr.showResultAndFit(cMin=0.1, cMax=60, cMap='viridis')
