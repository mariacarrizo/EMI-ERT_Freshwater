# %%
# %matplotlib widget

# %%
import numpy as np
import pygimli as pg
import empymod as ep
from scipy.constants import mu_0
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import pandas as pd
import sys
sys.path.insert(1, '../src')

from FDEM1D import FDEM1DModelling, LCModelling
from showStitched import showStitchedModels
from Plots import Plot2Datas, grid

# %%
# First step: check configuration of FDEM to perform forward
# Second step: check number of layers in FDEM1D Modelling forward class

# %%
models = np.load('models/model_slope5_f.npy')
data = np.load('data/data3D_slope5_f_sorted.pkl.npy', allow_pickle=True)
data = np.array(data)

# %%
inputs ={'label' : 'Electrical conductivity $\sigma$ [S/m]',
         'cMin': 10/1000,
         'cMax': 1500/1000}

showStitchedModels(models, zMax=10, title = 'True Model', **inputs)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <Axes: title={'center': 'True Model'}>

# %%
data_t = data.copy()

# %%
nLayers = np.shape(models)[1] -1
nLayers
# Out:
# 2

# %% [markdown]
# # Inversion

# %%
# Initial model
m0 = models.copy()

# 2 lay case
m0[:,:1] = 2
m0[:,1:] = 500/1000

m0 = m0.ravel()

# %% [markdown]
# ### L-curve criterion

# %%
lambdas = np.logspace(-1,2,30, endpoint=False)
lambdas
# Out:
# array([ 0.1       ,  0.12589254,  0.15848932,  0.19952623,  0.25118864,
#         0.31622777,  0.39810717,  0.50118723,  0.63095734,  0.79432823,
#         1.        ,  1.25892541,  1.58489319,  1.99526231,  2.51188643,
#         3.16227766,  3.98107171,  5.01187234,  6.30957344,  7.94328235,
#        10.        , 12.58925412, 15.84893192, 19.95262315, 25.11886432,
#        31.6227766 , 39.81071706, 50.11872336, 63.09573445, 79.43282347])

# %%
Lcurve = True

if Lcurve:
    # ertmanager.inv.phiModel() #x
    # ertmanager.inv.phiData() #y 
    #do it with the inverse of lambda? 
    print('RUNNING L CURVE CRITERION ')
    lambdas = np.logspace(-1,2,20)
        
    phimodels = []
    phidatas = []
    chis = []
    mods = {}

    pg.tic()
    for i, a in enumerate(lambdas):
        print(f'Now using LAMBDA {a} - {i} ITERATION ')
        LC = LCModelling(FDEM1DModelling)
        LC.initJacobian(dataVals=data_t, nLay=nLayers)
        LC.createJacobian(models)
        LC.constraint_matrix(data_t, nLay=nLayers)
        LC.normalization(data_t, cWeight_1=1, cWeight_2=1, nLay=nLayers)
        LC.createWeight(data_t, cWeight_1=1, cWeight_2=1, nLay=nLayers)
        LC.createConstraints()
        
        transData = pg.trans.TransLog()
        transThk = pg.trans.TransLogLU(1,5)
        transSig = pg.trans.TransLogLU(10/1000,2000/1000)

        LC.region(1).setTransModel(transThk)
        LC.region(2).setTransModel(transSig)

        data_true = np.array(data_t).ravel()
        relativeError = np.ones_like(data_true)*1e-3 # what is this for?

        inv = pg.Inversion(LC)
        inv.dataTrans = transData
        mod = inv.run(data_true, relativeError, startModel=m0, verbose=False, lam=a)
        phimodels.append(inv.phiModel())
        phidatas.append(inv.phiData())
        chis.append(inv.chi2())
        mods[a] = mod
    pg.toc()

    #first derivatives 
    dx= np.gradient(phimodels)
    dy = np.gradient(phidatas)

    #second derivatives 
    d2x = np.gradient(dx)
    d2y = np.gradient(dy)

    #calculation of curvature from the typical formula
    curvature = np.abs(dx * d2y - d2x * dy) / (dx * dx + dy * dy)**1.5
    print("The optimal alpha = ", lambdas[np.argmax(curvature)+1])

    plt.figure()
    plt.scatter(phimodels, phidatas, c='g')
    plt.xlabel('Phi Model')
    plt.ylabel('Phi Data')
    plt.title('L-curve analysis')
    for i, txt in enumerate(lambdas):
         txt = np.round(txt, 3)
         txt = str(txt)
         plt.annotate(txt, (phimodels[i], phidatas[i]))
    plt.plot(phimodels[np.argmax(curvature)+1], phidatas[np.argmax(curvature)+1], '+b')
    #plt.savefig(PATHPLOTS + 'Lcurveplot.jpg')
    plt.show()

    lamb_opt = lambdas[np.argmax(curvature)+1]
# Out:
# RUNNING L CURVE CRITERION
# Now using LAMBDA 0.1 - 0 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:20:39 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:20:39 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4b8bcb5800>
# Now using LAMBDA 0.14384498882876628 - 1 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:20:53 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:20:53 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4b8bcb76a0>
# Now using LAMBDA 0.20691380811147897 - 2 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:21:07 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:21:07 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4b8bd39a80>
# Now using LAMBDA 0.29763514416313175 - 3 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:21:21 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4b8bcb5cb0>
# 20/04/24 - 21:21:21 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# Now using LAMBDA 0.42813323987193935 - 4 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:21:34 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:21:35 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4b8bcb6ca0>
# Now using LAMBDA 0.6158482110660264 - 5 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:21:47 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:21:47 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4b8bd39120>
# Now using LAMBDA 0.8858667904100825 - 6 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:22:01 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:22:01 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4b8bcb6070>
# Now using LAMBDA 1.2742749857031335 - 7 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:22:13 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:22:13 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4ba1acabb0>
# Now using LAMBDA 1.8329807108324356 - 8 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:22:26 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:22:26 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4b8bcb7740>
# Now using LAMBDA 2.636650898730358 - 9 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:22:40 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:22:40 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4ba1ac9170>
# Now using LAMBDA 3.79269019073225 - 10 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:22:53 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:22:53 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4ba1ad7bf0>
# Now using LAMBDA 5.455594781168517 - 11 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:23:09 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:23:09 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4b8bcb5800>
# Now using LAMBDA 7.847599703514611 - 12 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:23:24 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:23:24 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4b8bcb7830>
# Now using LAMBDA 11.288378916846883 - 13 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:23:42 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:23:42 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4b8bd38b80>
# Now using LAMBDA 16.23776739188721 - 14 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:24:01 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:24:01 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4ba1acabb0>
# Now using LAMBDA 23.357214690901213 - 15 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:24:18 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:24:18 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4b8bd39f80>
# Now using LAMBDA 33.59818286283781 - 16 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:24:34 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:24:34 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4ba1ad5bc0>
# Now using LAMBDA 48.32930238571752 - 17 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:24:51 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:24:51 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4b8bd399e0>
# Now using LAMBDA 69.51927961775606 - 18 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:25:04 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:25:04 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4b8bcb7ce0>
# Now using LAMBDA 100.0 - 19 ITERATION
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:25:16 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:25:16 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4ba1acabb0>
# Elapsed time is 4 minutes and 48.61 seconds.
# The optimal alpha =  2.636650898730358
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lamb_opt = lambdas[np.argmax(curvature)+1]

# %%
LC = LCModelling(FDEM1DModelling)
LC.initJacobian(dataVals=data_t, nLay=nLayers)
LC.createJacobian(models)
LC.constraint_matrix(data_t, nLay=nLayers)
LC.normalization(data_t, cWeight_1=1, cWeight_2=1, nLay=nLayers)
LC.createWeight(data_t, cWeight_1=1, cWeight_2=1, nLay=nLayers)
LC.createConstraints()

transData = pg.trans.TransLog()
transThk = pg.trans.TransLogLU(1,5)
transSig = pg.trans.TransLogLU(10/1000,2000/1000)

LC.region(1).setTransModel(transThk)
LC.region(2).setTransModel(transSig)

data_true = np.array(data_t).ravel()
relativeError = np.ones_like(data_true)*1e-3 # what is this for?

inv = pg.Inversion(LC)
inv.dataTrans = transData
models_est = inv.run(data_true, relativeError, startModel=m0, verbose=False, lam= lamb_opt)
# Out:
# Inversion is normalized
# Jacobian size: 702 117 720
# 20/04/24 - 21:29:51 - Core - WARNING - no clear() implemented for:  18MatrixBase_wrapper
# 20/04/24 - 21:29:51 - Core - ERROR - no cWeights defined. You should create constraints matrix first.
# cWeights are equal
# Constraint cWeight length: 117
# CW:  <pygimli.math.matrix.MultLeftMatrix object at 0x7f4b8213cf40>

# %%
models_est = np.array(models_est).reshape(np.shape(models))

models_grid = grid(models)
models_est_grid = grid(models_est)
diff = 100*np.abs(models_grid - models_est_grid)/models_grid

# %%
fig, ax = plt.subplots(1,2)

inputs ={'label' : 'Electrical conductivity $\sigma$ [S/m]',
         'cMin': 10/1000,
         'cMax': 1500/1000, 
         'logScale':True, 
         'location':'right'}

showStitchedModels(ax = ax[1], models=models_est, zMax=10, 
                  title = 'Estimated Model LCI', **inputs)

showStitchedModels(ax = ax[0], models=models, zMax=10, 
                  title = 'True Model LCI', **inputs)
# Out:
# <Axes: title={'center': 'True Model LCI'}>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots()

c = ax.imshow(diff.T, extent=[0,40, -10,0], norm=colors.LogNorm(vmin=1, vmax=100))
fig.colorbar(c, ax=ax, location='bottom', )
plt.title('% Relative Difference')
# Out:
# Text(0.5, 1.0, '% Relative Difference')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# True data vs Inverted data

data_inv = np.array(inv.response)
data_inv = data_inv.reshape(np.shape(data_t))

Plot2Datas(data_t, data_inv)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
